# %%
from PIL import Image
from io import BytesIO
from transformers import CLIPProcessor, CLIPModel, SegformerImageProcessor, AutoModelForSemanticSegmentation , AutoFeatureExtractor
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import os
import weaviate
import numpy as np
import json
import cv2
import base64
# Out:
# c:\Users\Jayesh\AppData\Local\Programs\Python\Python39\lib\site-packages\bitsandbytes\cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# 'NoneType' object has no attribute 'cadam32bit_grad_fp32'

# %%
PATH = "D:\\Codes\\ziggy-ai\\scraping\\Pinterest"

# %%
client = weaviate.Client(url="http://localhost:8080")

# %%
# pinterest = open("pinterest.json", "r")
# pinterest_top = open("pinterest_top.json", "r")
# pinterest_bottom = open("pinterest_bottom.json", "r")
# pinterest_class = json.load(pinterest)
# pinterest_top_class = json.load(pinterest_top)
# pinterest_bottom_class = json.load(pinterest_bottom)
# pinterest.close()
# pinterest_top.close()
# pinterest_bottom.close()

# # client.schema.delete_all()
# client.schema.delete_class("PinterestImages")
# client.schema.delete_class("PinterestTop")
# client.schema.delete_class("PinterestBottom")
# client.schema.create_class(pinterest_top_class)
# client.schema.create_class(pinterest_bottom_class)
# client.schema.create_class(pinterest_class)

# %%
checkpoint = "patrickjohncyh/fashion-clip"
model = CLIPModel.from_pretrained(checkpoint)
processor = CLIPProcessor.from_pretrained(checkpoint)
seg_processor = SegformerImageProcessor.from_pretrained("mattmdjaga/segformer_b2_clothes")
seg_model = AutoModelForSemanticSegmentation.from_pretrained("mattmdjaga/segformer_b2_clothes")
# Out:
# c:\Users\Jayesh\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\models\segformer\image_processing_segformer.py:99: FutureWarning: The `reduce_labels` parameter is deprecated and will be removed in a future version. Please use `do_reduce_labels` instead.
#   warnings.warn(

# %%
def getImageEmbeddingsFromPath(image_path):
	image = Image.open(image_path)
	inputs = processor(text=["dummy"] , images=image, return_tensors="pt", padding=True)
	outputs = model(**inputs , return_dict=True)	
	return outputs["image_embeds"]

def getImageEmbeddings(image):
	inputs = processor(text=["dummy"] , images=image, return_tensors="pt", padding=True)
	outputs = model(**inputs , return_dict=True)
	return outputs["image_embeds"]

def applyMask(image, mask):
	image = np.array(image)
	mask = np.array(mask)
	mask = np.stack((mask,)*3, axis=-1)
	resultant = image*mask
	resultant[mask == 0] = 255
	return resultant

def cropImage(image):
	temp = image[:, :, ::-1].copy() 
	temp = temp.astype('uint8')
	gray = cv2.cvtColor(temp, cv2.COLOR_BGR2GRAY)
	thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
	contours = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)[0]
	contours = sorted(contours, key=lambda x: cv2.contourArea(x), reverse=True)
	x,y,w,h = cv2.boundingRect(contours[0])
	crop = image[y:y+h, x:x+w]
	return crop

def segment(image, to_mask):
	inputs = seg_processor(images=image, return_tensors="pt")
	outputs = seg_model(**inputs)
	logits = outputs.logits.cpu()
	upsampled_logits = nn.functional.interpolate(
		logits,
		size=image.size[::-1],
		mode="bilinear",
		align_corners=False,
	)
	pred_seg = upsampled_logits.argmax(dim=1)[0]
	result = []
	for i in to_mask:
		mask = pred_seg.numpy().copy()
		mask[mask != i] = 0
		mask[mask == i] = 1
		item = applyMask(image, mask)
		result.append(item)
	return result

def segmentAndEmbed(image_path, to_mask):
	result = {}
	image = Image.open(image_path)
	fullImageEmbedding = getImageEmbeddings(image)
	buffered = BytesIO()
	image.save(buffered, format="PNG")
	fullImageBase64 = base64.b64encode(buffered.getvalue()).decode()
	result["fullImageBase64"] = fullImageBase64
	result["fullImageEmbedding"] = fullImageEmbedding
	segments = segment(image, to_mask)
	for i in range(len(to_mask)):
		segmentEmbedding = getImageEmbeddings(segments[i])
		segments[i] = Image.fromarray(np.uint8(segments[i]))
		buffered = BytesIO()
		segments[i].save(buffered, format="PNG")
		segmentBase64 = base64.b64encode(buffered.getvalue()).decode()
		result[f"segmentBase64_{i}"] = segmentBase64
		result[f"segmentEmbedding_{i}"] = segmentEmbedding
	return result

# %%
df = pd.read_csv(f"{PATH}\\girls_collegewear.csv")
with client.batch(batch_size=100, num_workers=2) as batch:
    for index, row in df.iterrows():
        if os.path.exists(f"{PATH}\\girls_collegewear\\image_{index}.jpg"):
            try:
                output = segmentAndEmbed(f"{PATH}\\girls_collegewear\\image_{index}.jpg", [4, 6])
                pinterest_obj = {
                    "category" : "girls_collegewear",
                    "description" : row["Image Alt Text"],
                    "image" : output["fullImageBase64"]
                }
                pinterest_uuid = batch.add_data_object(pinterest_obj, "PinterestImages", vector=output["fullImageEmbedding"])
                pinterest_top_uuid = batch.add_data_object({"image" : output["segmentBase64_0"]}, "PinterestTop", vector=output["segmentEmbedding_0"])
                pinterest_bottom_uuid = batch.add_data_object({"image" : output["segmentBase64_1"]}, "PinterestBottom", vector=output["segmentEmbedding_1"])
                batch.add_reference(from_object_class_name="PinterestImages", to_object_class_name="PinterestTop", from_object_uuid=pinterest_uuid, to_object_uuid=pinterest_top_uuid, from_property_name="top")
                batch.add_reference(from_object_class_name="PinterestImages", to_object_class_name="PinterestBottom", from_object_uuid=pinterest_uuid, to_object_uuid=pinterest_bottom_uuid, from_property_name="bottom")
                print(f"Added {index} to Weaviate")
            except:
                print(f"Error adding {index} to Weaviate")
# Out:
# Added 1 to Weaviate
# Added 3 to Weaviate
# Added 4 to Weaviate
# Added 5 to Weaviate
# Added 6 to Weaviate
# Added 8 to Weaviate
# Added 9 to Weaviate
# Added 10 to Weaviate
# Added 11 to Weaviate
# Added 12 to Weaviate
# Added 13 to Weaviate
# Added 15 to Weaviate
# Added 17 to Weaviate
# Added 18 to Weaviate
# Added 19 to Weaviate
# Added 20 to Weaviate
# Added 21 to Weaviate
# Added 22 to Weaviate
# Added 24 to Weaviate
# Added 25 to Weaviate
# Added 27 to Weaviate
# Added 28 to Weaviate
# Added 29 to Weaviate
# Added 31 to Weaviate
# Added 35 to Weaviate
# Added 36 to Weaviate
# Added 37 to Weaviate
# Added 38 to Weaviate
# Added 39 to Weaviate
# Added 41 to Weaviate
# Added 42 to Weaviate
# Added 43 to Weaviate
# Added 44 to Weaviate
# Added 45 to Weaviate
# Added 46 to Weaviate
# Added 47 to Weaviate
# Added 48 to Weaviate
# Added 49 to Weaviate
# Added 50 to Weaviate
# Added 52 to Weaviate
# Added 53 to Weaviate
# Added 54 to Weaviate
# Added 55 to Weaviate
# Added 59 to Weaviate
# Added 61 to Weaviate
# Added 62 to Weaviate
# Added 63 to Weaviate
# Added 64 to Weaviate
# Added 68 to Weaviate
# Added 70 to Weaviate
# Added 72 to Weaviate
# Added 74 to Weaviate
# Added 75 to Weaviate
# Added 76 to Weaviate
# Added 77 to Weaviate
# Added 79 to Weaviate
# Error adding 80 to Weaviate
# Added 81 to Weaviate
# Added 83 to Weaviate
# Added 84 to Weaviate
# Added 86 to Weaviate
# Added 87 to Weaviate
# Added 88 to Weaviate
# Added 89 to Weaviate
# Added 91 to Weaviate
# Added 93 to Weaviate
# Added 94 to Weaviate
# Added 95 to Weaviate
# Added 97 to Weaviate
# Added 100 to Weaviate
# Added 102 to Weaviate
# Added 106 to Weaviate
# Added 107 to Weaviate
# Added 109 to Weaviate
# Added 112 to Weaviate
# Added 114 to Weaviate
# Added 117 to Weaviate
# Added 119 to Weaviate
# Added 121 to Weaviate
# Added 123 to Weaviate
# Added 124 to Weaviate
# Added 125 to Weaviate
# Added 126 to Weaviate
# Added 128 to Weaviate
# Added 129 to Weaviate
# Added 130 to Weaviate
# Added 131 to Weaviate
# Added 132 to Weaviate
# Added 135 to Weaviate
# Added 137 to Weaviate
# Added 138 to Weaviate
# Added 139 to Weaviate
# Added 140 to Weaviate
# Added 141 to Weaviate
# Error adding 142 to Weaviate
# Added 144 to Weaviate
# Added 145 to Weaviate
# Added 146 to Weaviate
# Added 147 to Weaviate
# Added 149 to Weaviate
# Added 152 to Weaviate
# Added 155 to Weaviate
# Added 156 to Weaviate
# Added 159 to Weaviate
# Added 160 to Weaviate
# Added 161 to Weaviate
# Added 162 to Weaviate
# Error adding 164 to Weaviate
# Added 165 to Weaviate
# Added 166 to Weaviate
# Added 167 to Weaviate
# Added 168 to Weaviate
# Added 172 to Weaviate
# Added 173 to Weaviate
# Added 176 to Weaviate
# Added 177 to Weaviate
# Added 178 to Weaviate
# Added 179 to Weaviate
# Added 180 to Weaviate
# Added 186 to Weaviate
# Added 187 to Weaviate
# Error adding 188 to Weaviate
# Added 189 to Weaviate
# Added 190 to Weaviate
# Added 191 to Weaviate
# Added 199 to Weaviate
# Added 207 to Weaviate
# Added 210 to Weaviate
# Added 211 to Weaviate
# Added 212 to Weaviate
# Added 213 to Weaviate
# Added 214 to Weaviate
# Added 216 to Weaviate
# Added 218 to Weaviate
# Added 219 to Weaviate
# Added 220 to Weaviate
# Added 221 to Weaviate
# Added 222 to Weaviate
# Added 224 to Weaviate
# Added 226 to Weaviate
# Added 227 to Weaviate
# Added 229 to Weaviate
# Added 231 to Weaviate
# Added 232 to Weaviate
# Added 233 to Weaviate
# Added 234 to Weaviate
# Added 235 to Weaviate
# Added 237 to Weaviate
# Added 238 to Weaviate
# Added 240 to Weaviate
# Added 242 to Weaviate
# Added 243 to Weaviate
# Added 246 to Weaviate
# Error adding 248 to Weaviate
# Added 250 to Weaviate
# Added 251 to Weaviate
# Added 255 to Weaviate
# Added 257 to Weaviate
# Error adding 259 to Weaviate
# Added 261 to Weaviate
# Added 263 to Weaviate
# Added 265 to Weaviate
# Added 266 to Weaviate
# Added 267 to Weaviate
# Added 268 to Weaviate
# Added 272 to Weaviate
# Added 274 to Weaviate
# Added 277 to Weaviate
# Added 280 to Weaviate
# Added 282 to Weaviate
# Added 283 to Weaviate
# Added 285 to Weaviate
# Added 287 to Weaviate
# Added 288 to Weaviate
# Added 289 to Weaviate
# Added 290 to Weaviate
# Added 291 to Weaviate
# Added 292 to Weaviate
# Added 293 to Weaviate
# Added 298 to Weaviate
# Added 299 to Weaviate
# Added 300 to Weaviate
# Added 301 to Weaviate
# Added 302 to Weaviate
# Added 303 to Weaviate
# Added 304 to Weaviate
# Error adding 305 to Weaviate
# Added 306 to Weaviate
# Added 307 to Weaviate
# Added 311 to Weaviate
# Added 313 to Weaviate
# Added 314 to Weaviate
# Added 315 to Weaviate
# Error adding 316 to Weaviate
# Added 317 to Weaviate
# Added 318 to Weaviate
# Added 320 to Weaviate
# Added 321 to Weaviate
# Added 322 to Weaviate
# Added 323 to Weaviate
# Added 327 to Weaviate
# Added 328 to Weaviate
# Error adding 330 to Weaviate
# Added 331 to Weaviate
# Added 332 to Weaviate
# Added 336 to Weaviate
# Error adding 337 to Weaviate
# Added 338 to Weaviate
# Added 340 to Weaviate
# Added 342 to Weaviate
# Added 343 to Weaviate
# Added 344 to Weaviate
# Added 347 to Weaviate
# Added 349 to Weaviate
# Added 350 to Weaviate
# Added 351 to Weaviate
# Added 353 to Weaviate
# Added 354 to Weaviate
# Added 355 to Weaviate
# Added 356 to Weaviate
# Added 357 to Weaviate
# Added 363 to Weaviate
# Added 366 to Weaviate
# Added 367 to Weaviate
# Added 368 to Weaviate
# Added 369 to Weaviate
# Added 371 to Weaviate
# Added 373 to Weaviate
# Added 376 to Weaviate
# Added 377 to Weaviate
# Added 378 to Weaviate
# Added 379 to Weaviate
# Added 380 to Weaviate
# Added 382 to Weaviate
# Error adding 383 to Weaviate
# Added 384 to Weaviate
# Added 386 to Weaviate
# Added 387 to Weaviate
# Added 389 to Weaviate
# Added 390 to Weaviate
# Added 392 to Weaviate
# Added 393 to Weaviate
# Error adding 394 to Weaviate
# Added 399 to Weaviate
# Added 400 to Weaviate
# Added 402 to Weaviate
# Added 403 to Weaviate
# Added 404 to Weaviate
# Added 405 to Weaviate
# Added 407 to Weaviate
# Added 414 to Weaviate
# Error adding 415 to Weaviate
# Added 421 to Weaviate
# Added 423 to Weaviate
# Added 425 to Weaviate
# Added 426 to Weaviate
# Error adding 427 to Weaviate
# Added 428 to Weaviate
# Added 431 to Weaviate
# Added 433 to Weaviate
# Added 434 to Weaviate
# Added 436 to Weaviate
# Added 441 to Weaviate
# Added 443 to Weaviate
# Added 444 to Weaviate
# Added 445 to Weaviate
# Added 449 to Weaviate
# Added 450 to Weaviate
# Added 452 to Weaviate
# Added 453 to Weaviate
# Added 459 to Weaviate
# Added 460 to Weaviate
# Added 462 to Weaviate
# Added 463 to Weaviate
# Added 464 to Weaviate
# Added 465 to Weaviate
# Added 466 to Weaviate
# Added 468 to Weaviate
# Added 469 to Weaviate
# Added 470 to Weaviate
# Added 471 to Weaviate
# Added 472 to Weaviate
# Error adding 473 to Weaviate
# Added 474 to Weaviate
# Added 477 to Weaviate
# Added 478 to Weaviate
# Added 479 to Weaviate
# Added 480 to Weaviate
# Added 481 to Weaviate
# Added 482 to Weaviate
# Error adding 483 to Weaviate
# Added 484 to Weaviate
# Added 485 to Weaviate
# Added 486 to Weaviate
# Added 488 to Weaviate
# Added 489 to Weaviate
# Added 491 to Weaviate
# Added 492 to Weaviate
# Added 494 to Weaviate
# Added 497 to Weaviate
# Added 498 to Weaviate
# Added 500 to Weaviate
# Error adding 501 to Weaviate
# Added 503 to Weaviate
# Added 507 to Weaviate
# Added 508 to Weaviate
# Added 511 to Weaviate
# Added 512 to Weaviate
# Added 513 to Weaviate
# Added 514 to Weaviate
# Added 516 to Weaviate
# Added 517 to Weaviate
# Added 518 to Weaviate
# Added 519 to Weaviate
# Added 520 to Weaviate
# Added 521 to Weaviate
# Added 522 to Weaviate
# Added 523 to Weaviate
# Added 525 to Weaviate
# Added 526 to Weaviate
# Added 527 to Weaviate
# Added 528 to Weaviate
# Added 529 to Weaviate
# Added 530 to Weaviate
# Added 534 to Weaviate
# Added 535 to Weaviate
# Added 536 to Weaviate
# Added 537 to Weaviate
# Added 542 to Weaviate
# Error adding 544 to Weaviate
# Added 552 to Weaviate
# Added 563 to Weaviate
# Added 564 to Weaviate
# Added 565 to Weaviate
# Added 567 to Weaviate
# Added 569 to Weaviate
# Added 570 to Weaviate
# Error adding 571 to Weaviate
# Added 572 to Weaviate
# Added 576 to Weaviate
# Added 577 to Weaviate
# Added 582 to Weaviate
# Added 583 to Weaviate
# Added 586 to Weaviate
# Added 587 to Weaviate
# Added 589 to Weaviate

# %%
segmentAndEmbed("pinterest_image.jpg", [4])
